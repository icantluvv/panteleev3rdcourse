# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
text = '''Погасло дневное светило;
На море синее вечерний пал туман.
Шуми, шуми, послушное ветрило,
Волнуйся подо мной, угрюмый океан.
Я вижу берег отдаленный,
Земли полуденной волшебные края;
С волненьем и тоской туда стремлюся я,
Воспоминаньем упоенный…
И чувствую: в очах родились слезы вновь;
Душа кипит и замирает;
Мечта знакомая вокруг меня летает;
Я вспомнил прежних лет безумную любовь,
И всё, чем я страдал, и всё, что сердцу мило,
Желаний и надежд томительный обман…
Шуми, шуми послушное ветрило,
Волнуйся подо мной, угрюмый океан.
Лети, корабль, неси меня к пределам дальным
По грозной прихоти обманчивых морей,
Но только не к брегам печальным
Туманной родины моей,
Страны, где пламенем страстей
Впервые чувства разгорались,
Где музы нежные мне тайно улыбались,
Где рано в бурях отцвела
Моя потерянная младость,
Где легкокрылая мне изменила радость
И сердце хладное страданью предала.
Искатель новых впечатлений,
Я вас бежал, отечески края;
Я вас бежал, питомцы наслаждений,
Минутной младости минутные друзья;
И вы, наперсницы порочных заблуждений,
Которым без любви я жертвовал собой,
Покоем, славою, свободой и душой,
И вы забыты мной, изменницы младые,
Подруги тайные моей весны златыя,
И вы забыты мной… Но прежних сердца ран,
Глубоких ран любви, ничто не излечило…
Шуми, шуми послушное ветрило,
Волнуйся подо мной, угрюмый океан…'''

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Погасло VERB nsubj
# дневное ADJ amod
# светило VERB obj
# ; PUNCT punct
#
#  SPACE dep
# На ADP case
# море NOUN obl
# синее ADJ amod
# вечерний NOUN nsubj
# пал VERB ROOT
# туман NOUN nsubj
# . PUNCT punct
#
#  SPACE dep
# Шуми NOUN nsubj
# , PUNCT punct
# шуми NOUN conj
# , PUNCT punct
# послушное VERB nsubj
# ветрило VERB conj
# , PUNCT punct
#
#  SPACE dep
# Волнуйся VERB acl
# подо ADP case
# мной PRON obl
# , PUNCT punct
# угрюмый VERB amod
# океан NOUN ROOT
# . PUNCT punct
#
#  SPACE dep
# Я PRON nsubj
# вижу VERB ROOT
# берег NOUN obj
# отдаленный ADJ amod
# , PUNCT punct
#
#  SPACE dep
# Земли PROPN conj
# полуденной ADJ amod
# волшебные ADJ amod
# края NOUN obj
# ; PUNCT punct
#
#  SPACE dep
# С ADP case
# волненьем NOUN obl
# и CCONJ cc
# тоской NOUN conj
# туда ADV advmod
# стремлюся VERB acl
# я PRON obj
# , PUNCT punct
#
#  SPACE dep
# Воспоминаньем PROPN obl
# упоенный ADJ amod
# … PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# чувствую VERB ROOT
# : PUNCT punct
# в ADP case
# очах NOUN obl
# родились VERB parataxis
# слезы NOUN nsubj
# вновь ADV advmod
# ; PUNCT punct
#
#  SPACE dep
# Душа NOUN nsubj
# кипит VERB conj
# и CCONJ cc
# замирает VERB conj
# ; PUNCT punct
#
#  SPACE dep
# Мечта NOUN nsubj
# знакомая NOUN nsubj
# вокруг ADP case
# меня PRON obl
# летает VERB parataxis
# ; PUNCT punct
#
#  SPACE dep
# Я PRON nsubj
# вспомнил VERB parataxis
# прежних ADJ amod
# лет NOUN obl
# безумную ADJ amod
# любовь NOUN obj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# всё PRON conj
# , PUNCT punct
# чем PRON mark
# я PRON nsubj
# страдал VERB acl:relcl
# , PUNCT punct
# и CCONJ cc
# всё PRON conj
# , PUNCT punct
# что SCONJ mark
# сердцу NOUN iobj
# мило ADV acl:relcl
# , PUNCT punct
#
#  SPACE dep
# Желаний NOUN conj
# и CCONJ cc
# надежд NOUN conj
# томительный ADJ amod
# обман NOUN nsubj
# … PUNCT punct
#
#  SPACE dep
# Шуми NOUN nsubj
# , PUNCT punct
# шуми NOUN nsubj
# послушное VERB amod
# ветрило VERB ROOT
# , PUNCT punct
#
#  SPACE dep
# Волнуйся VERB acl
# подо ADP case
# мной PRON obl
# , PUNCT punct
# угрюмый VERB amod
# океан NOUN conj
# . PUNCT punct
#
#  SPACE dep
# Лети NOUN nsubj
# , PUNCT punct
# корабль NOUN conj
# , PUNCT punct
# неси VERB ROOT
# меня PRON obj
# к ADP case
# пределам NOUN obl
# дальным ADJ xcomp
#
#  SPACE dep
# По ADP case
# грозной ADJ amod
# прихоти NOUN obl
# обманчивых ADJ amod
# морей NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Но CCONJ cc
# только PART advmod
# не PART advmod
# к ADP case
# брегам NOUN obl
# печальным ADJ amod
#
#  SPACE dep
# Туманной ADJ amod
# родины NOUN nmod
# моей DET det
# , PUNCT punct
#
#  SPACE dep
# Страны NOUN conj
# , PUNCT punct
# где ADV advmod
# пламенем NOUN obl
# страстей NOUN nmod
#
#  SPACE dep
# Впервые ADV advmod
# чувства NOUN nsubj
# разгорались VERB conj
# , PUNCT punct
#
#  SPACE dep
# Где ADV advmod
# музы NOUN nsubj
# нежные ADJ amod
# мне PRON iobj
# тайно ADV advmod
# улыбались VERB ccomp
# , PUNCT punct
#
#  SPACE dep
# Где ADV advmod
# рано ADV advmod
# в ADP case
# бурях NOUN obl
# отцвела VERB conj
#
#  SPACE dep
# Моя DET det
# потерянная ADJ amod
# младость NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# Где ADV advmod
# легкокрылая ADJ nsubj
# мне PRON iobj
# изменила VERB acl:relcl
# радость NOUN obj
#
#  SPACE dep
# И CCONJ cc
# сердце NOUN nsubj
# хладное VERB amod
# страданью NOUN obl
# предала VERB conj
# . PUNCT punct
#
#  SPACE dep
# Искатель NOUN nsubj
# новых ADJ amod
# впечатлений NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Я PRON nsubj
# вас PRON obj
# бежал VERB ROOT
# , PUNCT punct
# отечески NOUN obj
# края NOUN nmod
# ; PUNCT punct
#
#  SPACE dep
# Я PRON nsubj
# вас PRON obj
# бежал VERB ROOT
# , PUNCT punct
# питомцы NOUN nsubj
# наслаждений NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Минутной ADJ amod
# младости NOUN conj
# минутные ADJ amod
# друзья NOUN parataxis
# ; PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# вы PRON parataxis
# , PUNCT punct
# наперсницы NOUN appos
# порочных ADJ amod
# заблуждений NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Которым PRON iobj
# без ADP case
# любви NOUN obl
# я PRON nsubj
# жертвовал VERB acl:relcl
# собой PRON fixed
# , PUNCT punct
#
#  SPACE dep
# Покоем PROPN conj
# , PUNCT punct
# славою NOUN conj
# , PUNCT punct
# свободой NOUN conj
# и CCONJ cc
# душой NOUN conj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# вы PRON nsubj:pass
# забыты VERB conj
# мной PRON obl
# , PUNCT punct
# изменницы NOUN conj
# младые ADJ amod
# , PUNCT punct
#
#  SPACE dep
# Подруги NOUN conj
# тайные ADJ amod
# моей DET det
# весны NOUN nmod
# златыя NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# вы PRON nsubj:pass
# забыты VERB conj
# мной PRON obl
# … PUNCT punct
# Но CCONJ cc
# прежних ADJ amod
# сердца NOUN nsubj
# ран NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Глубоких ADJ amod
# ран NOUN conj
# любви NOUN nmod
# , PUNCT punct
# ничто PRON nsubj
# не PART advmod
# излечило VERB ROOT
# … PUNCT punct
#
#  SPACE dep
# Шуми NOUN nsubj
# , PUNCT punct
# шуми NOUN nsubj
# послушное VERB acl
# ветрило VERB ROOT
# , PUNCT punct
#
#  SPACE dep
# Волнуйся VERB acl
# подо ADP case
# мной PRON obl
# , PUNCT punct
# угрюмый VERB amod
# океан NOUN conj
# … PUNCT punct

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="f244163ac8924f32bc2ba4aff14463cd-0" class="displacy" width="41875" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Погасло</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">дневное</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">светило;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">На</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">море</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">синее</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">вечерний</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">пал</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">туман.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Шуми,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">шуми,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">послушное</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">ветрило,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Волнуйся</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">подо</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">мной,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">угрюмый</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">океан.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Я</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">вижу</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">берег</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">отдаленный,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Земли</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">полуденной</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">волшебные</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">края;</tspan>
#     <tspan class="displacy-tag" dy="2e
