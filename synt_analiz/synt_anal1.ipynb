# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
text = '''Воспоминаньями смущенный,
Исполнен сладкою тоской,
Сады прекрасные, под сумрак ваш священный
Вхожу с поникшею главой.
Так отрок библии, безумный расточитель,
До капли истощив раскаянья фиал,
Увидев наконец родимую обитель,
Главой поник и зарыдал.
В пылу восторгов скоротечных,
В бесплодном вихре суеты,
О, много расточил сокровищ я сердечных
За недоступные мечты,
И долго я блуждал, и часто, утомленный,
Раскаяньем горя, предчувствуя беды,
Я думал о тебе, предел благословенный,
Воображал сии сады.
Воображаю день счастливый,
Когда средь вас возник лицей,
И слышу наших игр я снова шум игривый
И вижу вновь семью друзей.
Вновь нежным отроком, то пылким, то ленивым,
Мечтанья смутные в груди моей тая,
Скитаясь по лугам, по рощам молчаливым,
Поэтом забываюсь я.
И въявь я вижу пред собою
Дней прошлых гордые следы.
Еще исполнены великою женою,
Ее любимые сады
Стоят населены чертогами, вратами,
Столпами, башнями, кумирами богов
И славой мраморной, и медными хвалами
Екатерининских орлов.
Садятся призраки героев
У посвященных им столпов,
Глядите: вот герой, стеснитель ратных строев,
Перун кагульских берегов.
Вот, вот могучий вождь полунощного флага,
Пред кем морей пожар и плавал и летал.
Вот верный брат его, герой Архипелага,
Вот наваринский Ганнибал.
Среди святых воспоминаний
Я с детских лет здесь возрастал,
А глухо между тем поток народной брани
Уж бесновался и роптал.
Отчизну обняла кровавая забота,
Россия двинулась, и мимо нас летят
И тучи конные, брадатая пехота,
И пушек светлый ряд.
На юных ратников завистливо взирали,
Ловили с жадностью мы брани дальный звук,
И, негодуя, мы и детство проклинали,
И узы строгие наук.
И многих не пришло. При звуке песней новых
Почили славные в полях Бородина,
На Кульмских высотах, в лесах Литвы суровых,
Вблизи Монмартра.'''

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Воспоминаньями NOUN obl
# смущенный ADJ ROOT
# , PUNCT punct
#
#  SPACE dep
# Исполнен PROPN conj
# сладкою NOUN nmod
# тоской NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Сады PROPN nsubj
# прекрасные ADJ conj
# , PUNCT punct
# под ADP case
# сумрак NOUN obl
# ваш DET det
# священный ADJ amod
#
#  SPACE dep
# Вхожу NOUN obj
# с ADP case
# поникшею NOUN nmod
# главой NOUN appos
# . PUNCT punct
#
#  SPACE dep
# Так ADV advmod
# отрок NOUN obj
# библии NOUN nmod
# , PUNCT punct
# безумный ADJ amod
# расточитель NOUN conj
# , PUNCT punct
#
#  SPACE dep
# До ADP case
# капли NOUN obl
# истощив VERB conj
# раскаянья NOUN flat:name
# фиал NOUN obj
# , PUNCT punct
#
#  SPACE dep
# Увидев VERB acl
# наконец ADV advmod
# родимую VERB amod
# обитель NOUN obj
# , PUNCT punct
#
#  SPACE dep
# Главой NOUN conj
# поник NOUN conj
# и CCONJ cc
# зарыдал VERB ROOT
# . PUNCT punct
#
#  SPACE dep
# В ADP case
# пылу NOUN obl
# восторгов NOUN nmod
# скоротечных ADJ nmod
# , PUNCT punct
#
#  SPACE dep
# В ADP case
# бесплодном ADJ amod
# вихре NOUN conj
# суеты NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# О INTJ punct
# , PUNCT punct
# много ADV advmod
# расточил VERB ROOT
# сокровищ NOUN obj
# я PRON nsubj
# сердечных ADJ amod
#
#  SPACE dep
# За ADP case
# недоступные ADJ amod
# мечты NOUN obl
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# долго ADV advmod
# я PRON nsubj
# блуждал VERB conj
# , PUNCT punct
# и CCONJ cc
# часто ADV orphan
# , PUNCT punct
# утомленный ADJ conj
# , PUNCT punct
#
#  SPACE dep
# Раскаяньем NOUN conj
# горя NOUN nmod
# , PUNCT punct
# предчувствуя VERB advcl
# беды NOUN obj
# , PUNCT punct
#
#  SPACE dep
# Я PRON nsubj
# думал VERB conj
# о ADP case
# тебе PRON obl
# , PUNCT punct
# предел NOUN nsubj
# благословенный ADJ conj
# , PUNCT punct
#
#  SPACE dep
# Воображал VERB conj
# сии NOUN iobj
# сады NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Воображаю VERB nsubj
# день NOUN obj
# счастливый ADJ ROOT
# , PUNCT punct
#
#  SPACE dep
# Когда SCONJ mark
# средь ADV advmod
# вас PRON nmod
# возник VERB advcl
# лицей NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# слышу VERB conj
# наших DET det
# игр NOUN obj
# я PRON nsubj
# снова ADV advmod
# шум NOUN conj
# игривый ADJ amod
#
#  SPACE dep
# И CCONJ cc
# вижу VERB conj
# вновь ADV advmod
# семью NOUN obj
# друзей NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Вновь ADV advmod
# нежным ADJ amod
# отроком NOUN obl
# , PUNCT punct
# то SCONJ mark
# пылким ADJ conj
# , PUNCT punct
# то SCONJ mark
# ленивым ADJ conj
# , PUNCT punct
#
#  SPACE dep
# Мечтанья PROPN conj
# смутные VERB amod
# в ADP case
# груди NOUN obl
# моей DET det
# тая NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Скитаясь VERB conj
# по ADP case
# лугам NOUN obl
# , PUNCT punct
# по ADP case
# рощам NOUN obl
# молчаливым ADJ conj
# , PUNCT punct
#
#  SPACE dep
# Поэтом PROPN obl
# забываюсь VERB ROOT
# я PRON nsubj
# . PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# въявь NOUN obj
# я PRON nsubj
# вижу VERB ROOT
# пред ADP case
# собою NOUN obl
#
#  SPACE dep
# Дней NOUN obj
# прошлых ADJ nmod
# гордые ADJ amod
# следы NOUN obj
# . PUNCT punct
#
#  SPACE dep
# Еще ADV advmod
# исполнены VERB ROOT
# великою NOUN nsubj:pass
# женою NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Ее DET det
# любимые ADJ amod
# сады NOUN nsubj
#
#  SPACE dep
# Стоят VERB conj
# населены VERB xcomp
# чертогами NOUN obl
# , PUNCT punct
# вратами NOUN conj
# , PUNCT punct
#
#  SPACE dep
# Столпами NOUN conj
# , PUNCT punct
# башнями NOUN conj
# , PUNCT punct
# кумирами NOUN conj
# богов NOUN nmod
#
#  SPACE dep
# И CCONJ cc
# славой ADJ amod
# мраморной ADJ amod
# , PUNCT punct
# и CCONJ cc
# медными ADJ conj
# хвалами NOUN nmod
#
#  SPACE dep
# Екатерининских ADJ amod
# орлов NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Садятся VERB ROOT
# призраки NOUN nsubj
# героев NOUN nmod
#
#  SPACE dep
# У ADP case
# посвященных VERB acl
# им PRON iobj
# столпов NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Глядите VERB conj
# : PUNCT punct
# вот PART advmod
# герой NOUN parataxis
# , PUNCT punct
# стеснитель NOUN conj
# ратных ADJ amod
# строев NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Перун PROPN conj
# кагульских ADJ amod
# берегов NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Вот PART ROOT
# , PUNCT punct
# вот PART advmod
# могучий ADJ amod
# вождь NOUN nsubj
# полунощного ADJ amod
# флага NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Пред NOUN conj
# кем PRON obl
# морей NOUN obj
# пожар NOUN obj
# и CCONJ cc
# плавал VERB conj
# и CCONJ cc
# летал VERB conj
# . PUNCT punct
#
#  SPACE dep
# Вот PART advmod
# верный ADJ amod
# брат NOUN ROOT
# его PRON nmod
# , PUNCT punct
# герой NOUN appos
# Архипелага PROPN nmod
# , PUNCT punct
#
#  SPACE dep
# Вот PART advmod
# наваринский ADJ amod
# Ганнибал PROPN conj
# . PUNCT punct
#
#  SPACE dep
# Среди ADP case
# святых ADJ amod
# воспоминаний NOUN obl
#
#  SPACE dep
# Я PRON nsubj
# с ADP case
# детских ADJ amod
# лет NOUN obl
# здесь ADV advmod
# возрастал VERB ROOT
# , PUNCT punct
#
#  SPACE dep
# А CCONJ cc
# глухо NOUN obj
# между ADP case
# тем PRON nmod
# поток NOUN nsubj
# народной ADJ amod
# брани NOUN nmod
#
#  SPACE dep
# Уж PART advmod
# бесновался VERB conj
# и CCONJ cc
# роптал VERB conj
# . PUNCT punct
#
#  SPACE dep
# Отчизну PROPN obj
# обняла VERB ROOT
# кровавая ADJ amod
# забота NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# Россия PROPN nsubj
# двинулась VERB conj
# , PUNCT punct
# и CCONJ cc
# мимо ADP case
# нас PRON obl
# летят VERB conj
#
#  SPACE dep
# И CCONJ cc
# тучи NOUN nsubj
# конные ADJ amod
# , PUNCT punct
# брадатая ADJ conj
# пехота NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# пушек NOUN conj
# светлый ADJ amod
# ряд NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# На ADP case
# юных ADJ amod
# ратников NOUN obl
# завистливо ADV advmod
# взирали VERB ROOT
# , PUNCT punct
#
#  SPACE dep
# Ловили VERB conj
# с ADP case
# жадностью NOUN obl
# мы PRON nsubj
# брани NOUN conj
# дальный ADJ amod
# звук NOUN obj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# , PUNCT punct
# негодуя ADV advcl
# , PUNCT punct
# мы PRON nsubj
# и PART advmod
# детство NOUN obj
# проклинали VERB conj
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# узы NOUN conj
# строгие ADJ amod
# наук NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# многих NUM nsubj
# не PART advmod
# пришло VERB ROOT
# . PUNCT punct
# При ADP case
# звуке NOUN obl
# песней NOUN nmod
# новых ADJ nmod
#
#  SPACE dep
# Почили VERB ROOT
# славные VERB nsubj
# в ADP case
# полях NOUN obl
# Бородина PROPN nmod
# , PUNCT punct
#
#  SPACE dep
# На ADP case
# Кульмских ADJ amod
# высотах NOUN conj
# , PUNCT punct
# в ADP case
# лесах NOUN conj
# Литвы PROPN nmod
# суровых ADJ obl
# , PUNCT punct
#
#  SPACE dep
# Вблизи ADP case
# Монмартра PROPN obl
# . PUNCT punct

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="474a2ce24bcf4b6abd34d6fd416e0372-0" class="displacy" width="56575" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Воспоминаньями</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">смущенный,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Исполнен</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">сладкою</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">тоской,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Сады</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">прекрасные,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">под</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">сумрак</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">ваш</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">священный</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Вхожу</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">с</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">поникшею</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">главой.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Так</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">отрок</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">библии,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">безумный</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">расточитель,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">До</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">капли</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">истощив</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">раскаянья</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">фиал,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">
# </tspan>
#     <tspan class="displacy-t
