# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
text = '''Прощай, письмо любви! прощай: она велела.
Как долго медлил я! как долго не хотела
Рука предать огню все радости мои!..
Но полно, час настал. Гори, письмо любви.
Готов я; ничему душа моя не внемлет.
Уж пламя жадное листы твои приемлет…
Минуту!.. вспыхнули! пылают — легкий дым
Виясь, теряется с молением моим.
Уж перстня верного утратя впечатленье,
Растопленный сургуч кипит… О провиденье!
Свершилось! Темные свернулися листы;
На легком пепле их заветные черты
Белеют… Грудь моя стеснилась. Пепел милый,
Отрада бедная в судьбе моей унылой,
Останься век со мной на горестной груди…'''

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Прощай VERB ROOT
# , PUNCT punct
# письмо NOUN obj
# любви NOUN nmod
# ! PUNCT punct
# прощай VERB ROOT
# : PUNCT punct
# она PRON nsubj
# велела VERB parataxis
# . PUNCT punct
#
#  SPACE dep
# Как ADV advmod
# долго ADV advmod
# медлил VERB ROOT
# я PRON nsubj
# ! PUNCT punct
# как ADV advmod
# долго ADV advmod
# не PART advmod
# хотела VERB ROOT
#
#  SPACE dep
# Рука NOUN nsubj
# предать VERB xcomp
# огню NOUN iobj
# все DET det
# радости NOUN obj
# мои DET det
# ! PUNCT punct
# .. PUNCT punct
#
#  SPACE dep
# Но CCONJ cc
# полно ADV parataxis
# , PUNCT punct
# час NOUN nsubj
# настал VERB ROOT
# . PUNCT punct
# Гори PROPN ROOT
# , PUNCT punct
# письмо NOUN conj
# любви NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Готов ADJ ROOT
# я PRON nsubj
# ; PUNCT punct
# ничему VERB amod
# душа NOUN obj
# моя DET det
# не PART advmod
# внемлет VERB conj
# . PUNCT punct
#
#  SPACE dep
# Уж PART advmod
# пламя NOUN nsubj
# жадное ADJ amod
# листы NOUN nmod
# твои DET det
# приемлет VERB ROOT
# … PUNCT punct
#
#  SPACE dep
# Минуту NOUN ROOT
# ! PUNCT punct
# .. PUNCT punct
# вспыхнули VERB ROOT
# ! PUNCT punct
# пылают VERB ROOT
# — PUNCT punct
# легкий ADJ amod
# дым NOUN parataxis
#
#  SPACE dep
# Виясь VERB iobj
# , PUNCT punct
# теряется VERB conj
# с ADP case
# молением NOUN obl
# моим DET det
# . PUNCT punct
#
#  SPACE dep
# Уж PART advmod
# перстня NOUN nsubj
# верного ADJ amod
# утратя NOUN ROOT
# впечатленье NOUN iobj
# , PUNCT punct
#
#  SPACE dep
# Растопленный ADJ amod
# сургуч NOUN nsubj
# кипит VERB conj
# … PUNCT punct
# О ADP case
# провиденье NOUN obl
# ! PUNCT punct
#
#  SPACE dep
# Свершилось VERB ROOT
# ! PUNCT punct
# Темные ADJ amod
# свернулися VERB amod
# листы NOUN nsubj
# ; PUNCT punct
#
#  SPACE dep
# На ADP case
# легком ADJ amod
# пепле NOUN nmod
# их DET det
# заветные ADJ amod
# черты NOUN nsubj
#
#  SPACE dep
# Белеют VERB ROOT
# … PUNCT punct
# Грудь NOUN nsubj
# моя DET det
# стеснилась VERB ROOT
# . PUNCT punct
# Пепел NOUN ROOT
# милый ADJ amod
# , PUNCT punct
#
#  SPACE dep
# Отрада PROPN conj
# бедная ADJ amod
# в ADP case
# судьбе NOUN nmod
# моей DET det
# унылой NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Останься VERB conj
# век NOUN obj
# со ADP case
# мной PRON nmod
# на ADP case
# горестной ADJ amod
# груди NOUN obl
# … PUNCT punct

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="380f988856f54c6da69f4250e9564ca2-0" class="displacy" width="18075" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Прощай,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">письмо</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">любви!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">прощай:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">она</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">велела.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Как</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">долго</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">медлил</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">я!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">как</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">долго</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">не</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">хотела</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Рука</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">предать</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">огню</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">все</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">радости</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">мои!..</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Но</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">полно,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">час</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">настал.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Гори,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">письмо</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">любви.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x
