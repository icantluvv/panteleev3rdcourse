# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
text = '''…Вновь я посетил
Тот уголок земли, где я провел
Изгнанником два года незаметных.
Уж десять лет ушло с тех пор — и много
Переменилось в жизни для меня,
И сам, покорный общему закону,
Переменился я — но здесь опять
Минувшее меня объемлет живо,
И, кажется, вечор еще бродил
Я в этих рощах.
Вот опальный домик,
Где жил я с бедной нянею моей.
Уже старушки нет — уж за стеною
Не слышу я шагов ее тяжелых,
Ни кропотливого ее дозора.
Вот холм лесистый, над которым часто
Я сиживал недвижим — и глядел
На озеро, воспоминая с грустью
Иные берега, иные волны…
Меж нив златых и пажитей зеленых
Оно синея стелется широко;
Через его неведомые воды
Плывет рыбак и тянет за собою
Убогий невод. По брегам отлогим
Рассеяны деревни — там за ними
Скривилась мельница, насилу крылья
Ворочая при ветре…
На границе
Владений дедовских, на месте том,
Где в гору подымается дорога,
Изрытая дождями, три сосны
Стоят — одна поодаль, две другие
Друг к дружке близко, — здесь, когда их мимо
Я проезжал верхом при свете лунном,
Знакомым шумом шорох их вершин
Меня приветствовал. По той дороге
Теперь поехал я и пред собою
Увидел их опять. Они всё те же,
Все тот же их знакомый уху шорох —
Но около корней их устарелых
(Где некогда все было пусто, голо)
Теперь младая роща разрослась,
Зеленая семья, кусты теснятся
Под сенью их как дети. А вдали
Стоит один угрюмый их товарищ,
Как старый холостяк, и вкруг него
По-прежнему все пусто.Здравствуй, племя
Младое, незнакомое! не я
Увижу твой могучий поздний возраст,
Когда перерастешь моих знакомцев
И старую главу их заслонишь
От глаз прохожего. Но пусть мой внук
Услышит ваш приветный шум, когда,
С приятельской беседы возвращаясь,
Веселых и приятных мыслей полон,
Пройдет он мимо вас во мраке ночи
И обо мне вспомянет.'''

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# … PUNCT ROOT
# Вновь ADV advmod
# я PRON nsubj
# посетил VERB ROOT
#
#  SPACE dep
# Тот DET det
# уголок NOUN obj
# земли NOUN nmod
# , PUNCT punct
# где ADV advmod
# я PRON nsubj
# провел VERB acl:relcl
#
#  SPACE dep
# Изгнанником PROPN iobj
# два NUM nummod:gov
# года NOUN obl
# незаметных ADJ nmod
# . PUNCT punct
#
#  SPACE dep
# Уж PART advmod
# десять NUM nummod:gov
# лет NOUN nsubj
# ушло VERB ROOT
# с ADV nsubj
# тех DET fixed
# пор NOUN fixed
# — PUNCT punct
# и CCONJ cc
# много ADV advmod
#
#  SPACE dep
# Переменилось VERB parataxis
# в ADP case
# жизни NOUN obl
# для ADP case
# меня PRON nmod
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# сам ADJ acl
# , PUNCT punct
# покорный VERB conj
# общему ADJ amod
# закону NOUN iobj
# , PUNCT punct
#
#  SPACE dep
# Переменился VERB conj
# я PRON nsubj
# — PUNCT punct
# но CCONJ cc
# здесь ADV advmod
# опять ADV advmod
#
#  SPACE dep
# Минувшее VERB amod
# меня PRON obj
# объемлет NOUN nsubj
# живо ADJ advmod
# , PUNCT punct
#
#  SPACE dep
# И CCONJ cc
# , PUNCT punct
# кажется VERB parataxis
# , PUNCT punct
# вечор NOUN nsubj
# еще ADV advmod
# бродил VERB conj
#
#  SPACE dep
# Я PRON nsubj
# в ADP case
# этих DET det
# рощах NOUN obl
# . PUNCT punct
#
#  SPACE dep
# Вот PART advmod
# опальный ADJ amod
# домик NOUN ROOT
# , PUNCT punct
#
#  SPACE dep
# Где ADV advmod
# жил VERB acl:relcl
# я PRON nsubj
# с ADP case
# бедной ADJ amod
# нянею ADJ obl
# моей DET det
# . PUNCT punct
#
#  SPACE dep
# Уже ADV advmod
# старушки NOUN nsubj
# нет VERB ROOT
# — PUNCT punct
# уж PART advmod
# за ADP case
# стеною NOUN obl
#
#  SPACE dep
# Не PART advmod
# слышу VERB parataxis
# я PRON nsubj
# шагов NOUN obj
# ее DET det
# тяжелых ADJ amod
# , PUNCT punct
#
#  SPACE dep
# Ни CCONJ advmod
# кропотливого ADJ conj
# ее DET det
# дозора NOUN nmod
# . PUNCT punct
#
#  SPACE dep
# Вот PART ROOT
# холм NOUN nsubj
# лесистый ADJ amod
# , PUNCT punct
# над ADP case
# которым PRON obl
# часто ADV advmod
#
#  SPACE dep
# Я PRON nsubj
# сиживал VERB acl:relcl
# недвижим ADJ obj
# — PUNCT punct
# и CCONJ cc
# глядел VERB parataxis
#
#  SPACE dep
# На ADP case
# озеро NOUN obl
# , PUNCT punct
# воспоминая VERB acl
# с ADP case
# грустью NOUN obl
#
#  SPACE dep
# Иные ADJ amod
# берега NOUN nmod
# , PUNCT punct
# иные ADJ amod
# волны NOUN conj
# … PUNCT punct
#
#  SPACE dep
# Меж NOUN nsubj
# нив PROPN nmod
# златых VERB nmod
# и CCONJ cc
# пажитей NOUN conj
# зеленых ADJ conj
#
#  SPACE dep
# Оно PRON nsubj
# синея NOUN nmod
# стелется VERB ROOT
# широко ADV advmod
# ; PUNCT punct
#
#  SPACE dep
# Через ADP case
# его DET det
# неведомые ADJ amod
# воды NOUN obl
#
#  SPACE dep
# Плывет PROPN ROOT
# рыбак NOUN nsubj
# и CCONJ cc
# тянет VERB conj
# за ADP case
# собою NOUN obl
#
#  SPACE dep
# Убогий ADJ amod
# невод NOUN obj
# . PUNCT punct
# По ADP case
# брегам NOUN obl
# отлогим ADJ amod
#
#  SPACE dep
# Рассеяны PROPN nmod
# деревни NOUN nmod
# — PUNCT punct
# там ADV advmod
# за ADP case
# ними PRON obl
#
#  SPACE dep
# Скривилась VERB ROOT
# мельница NOUN nsubj
# , PUNCT punct
# насилу NOUN obj
# крылья NOUN nmod
#
#  SPACE dep
# Ворочая VERB conj
# при ADP case
# ветре NOUN obl
# … PUNCT punct
#
#  SPACE dep
# На ADP case
# границе NOUN ROOT
#
#  SPACE dep
# Владений NOUN nmod
# дедовских ADJ nmod
# , PUNCT punct
# на ADP case
# месте NOUN conj
# том PRON nmod
# , PUNCT punct
#
#  SPACE dep
# Где ADV advmod
# в ADP case
# гору NOUN obl
# подымается VERB acl
# дорога NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# Изрытая VERB acl
# дождями NOUN obl
# , PUNCT punct
# три NUM nummod:gov
# сосны NOUN nsubj
#
#  SPACE dep
# Стоят VERB conj
# — PUNCT punct
# одна NUM nummod
# поодаль NOUN parataxis
# , PUNCT punct
# две NUM nummod:gov
# другие ADJ conj
#
#  SPACE dep
# Друг PRON obl
# к ADP case
# дружке NOUN obl
# близко ADV advmod
# , PUNCT punct
# — PUNCT punct
# здесь ADV parataxis
# , PUNCT punct
# когда SCONJ mark
# их PRON obj
# мимо ADV advmod
#
#  SPACE dep
# Я PRON nsubj
# проезжал VERB advcl
# верхом NOUN advmod
# при ADP case
# свете NOUN obl
# лунном NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# Знакомым ADJ amod
# шумом NOUN conj
# шорох NOUN nmod
# их PRON det
# вершин NOUN nmod
#
#  SPACE dep
# Меня PRON obj
# приветствовал VERB conj
# . PUNCT punct
# По ADP case
# той DET det
# дороге NOUN obl
#
#  SPACE dep
# Теперь ADV advmod
# поехал VERB ROOT
# я PRON nsubj
# и CCONJ cc
# пред ADP case
# собою NOUN obl
#
#  SPACE dep
# Увидел VERB conj
# их PRON obj
# опять ADV advmod
# . PUNCT punct
# Они PRON nsubj
# всё DET det
# те DET ROOT
# же PART advmod
# , PUNCT punct
#
#  SPACE dep
# Все DET det
# тот DET det
# же PART advmod
# их PRON det
# знакомый ADJ amod
# уху NOUN conj
# шорох NOUN nmod
# — PUNCT punct
#
#  SPACE dep
# Но CCONJ cc
# около ADP case
# корней NOUN orphan
# их PRON nmod
# устарелых ADJ nmod
#
#  SPACE dep
# ( PUNCT punct
# Где ADV advmod
# некогда ADV advmod
# все PRON nsubj
# было AUX cop
# пусто NOUN parataxis
# , PUNCT punct
# голо NOUN conj
# ) PUNCT punct
#
#  SPACE dep
# Теперь ADV advmod
# младая ADJ amod
# роща PROPN nsubj
# разрослась VERB conj
# , PUNCT punct
#
#  SPACE dep
# Зеленая ADJ amod
# семья NOUN conj
# , PUNCT punct
# кусты NOUN nsubj
# теснятся VERB conj
#
#  SPACE dep
# Под ADP case
# сенью NOUN obl
# их PRON nmod
# как SCONJ case
# дети NOUN obl
# . PUNCT punct
# А CCONJ cc
# вдали ADV advmod
#
#  SPACE dep
# Стоит VERB ROOT
# один NUM nummod
# угрюмый VERB amod
# их PRON nmod
# товарищ NOUN nsubj
# , PUNCT punct
#
#  SPACE dep
# Как SCONJ mark
# старый ADJ amod
# холостяк NOUN obl
# , PUNCT punct
# и CCONJ cc
# вкруг ADV advmod
# него PRON obl
#
#  SPACE dep
# По ADV advmod
# - ADV advmod
# прежнему ADV advmod
# все PRON nsubj
# пусто ADJ conj
# . PUNCT punct
# Здравствуй VERB ROOT
# , PUNCT punct
# племя NOUN obl
#
#  SPACE dep
# Младое PROPN nmod
# , PUNCT punct
# незнакомое ADJ conj
# ! PUNCT punct
# не PART advmod
# я PRON nsubj
#
#  SPACE dep
# Увижу VERB ROOT
# твой DET det
# могучий ADJ amod
# поздний ADJ amod
# возраст NOUN obj
# , PUNCT punct
#
#  SPACE dep
# Когда SCONJ mark
# перерастешь VERB advcl
# моих DET det
# знакомцев NOUN obj
#
#  SPACE dep
# И CCONJ cc
# старую ADJ amod
# главу NOUN obj
# их PRON obj
# заслонишь VERB ccomp
#
#  SPACE dep
# От ADP case
# глаз NOUN obl
# прохожего NOUN nmod
# . PUNCT punct
# Но CCONJ cc
# пусть PART advmod
# мой DET det
# внук NOUN nsubj
#
#  SPACE dep
# Услышит VERB ROOT
# ваш DET det
# приветный ADJ amod
# шум NOUN obj
# , PUNCT punct
# когда SCONJ mark
# , PUNCT punct
#
#  SPACE dep
# С ADP case
# приятельской ADJ amod
# беседы NOUN obl
# возвращаясь VERB advcl
# , PUNCT punct
#
#  SPACE dep
# Веселых ADJ amod
# и CCONJ cc
# приятных ADJ conj
# мыслей NOUN nsubj
# полон ADJ conj
# , PUNCT punct
#
#  SPACE dep
# Пройдет VERB conj
# он PRON nsubj
# мимо ADP case
# вас PRON obl
# во ADP case
# мраке NOUN obl
# ночи NOUN nmod
#
#  SPACE dep
# И CCONJ cc
# обо ADP case
# мне PRON obl
# вспомянет VERB conj
# . PUNCT punct

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="cc41ed1eecbf48c48cf45cd8d5232451-0" class="displacy" width="60950" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">…</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Вновь</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">я</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">посетил</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Тот</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">уголок</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">земли,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">где</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">я</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">провел</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Изгнанником</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">два</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">года</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">незаметных.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Уж</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">десять</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">лет</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">ушло</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">с</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">тех</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">пор —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">много</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Переменилось</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">в</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">жизни</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">для</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP</ts
